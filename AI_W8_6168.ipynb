# %% [markdown]
# <a href="https://colab.research.google.com/github/ARPRAHMAN/AI_Problems/blob/main/AI_W8_6168.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Deed Neural Network (Context settings)**
#
#
# *   Feature Learning
# *   Feature Sequential model develop
#
# *   Traning Essential
# *   Validity of performance

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Adjust the path to your file location
file_path = '/content/drive/MyDrive/AI_dataset/Churn_Modelling.csv'
df = pd.read_csv(file_path)

# Check the first few rows of the dataset
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
# 6       7       0.00              2          1               1
# 7       4  115046.74              4          1               0
# 8       4  142051.07              2          0               1
# 9       2  134603.88              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# 5        149756.71       1
# 6         10062.80       0
# 7        119346.88       1
# 8         74940.50       0
# 9         71725.73       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df.drop(columns=['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# for convert string to numeric use **GET DUMMYES** for encoding.

# %%
df = pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1              False
# 1               1        112542.58       0              False
# 2               0        113931.57       1              False
# 3               0         93826.63       0              False
# 4               1         79084.10       0              False
#
#    Geography_Spain  Gender_Male
# 0            False        False
# 1             True        False
# 2            False        False
# 3            False        False
# 4             True        False

# %%
x = df.drop(columns=['Exited'])
y = df['Exited'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# Deviation Minimal for everyone that's why use **standard scaler**

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
x_train_scaled
# Out:
# array([[ 0.16958176, -0.46460796,  0.00666099, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-2.30455945,  0.30102557, -1.37744033, ...,  1.75486502,
#         -0.57369368,  0.91601335],
#        [-1.19119591, -0.94312892, -1.031415  , ..., -0.5698444 ,
#         -0.57369368, -1.09168714],
#        ...,
#        [ 0.9015152 , -0.36890377,  0.00666099, ..., -0.5698444 ,
#         -0.57369368,  0.91601335],
#        [-0.62420521, -0.08179119,  1.39076231, ..., -0.5698444 ,
#          1.74309049, -1.09168714],
#        [-0.28401079,  0.87525072, -1.37744033, ...,  1.75486502,
#         -0.57369368, -1.09168714]])

# %% [markdown]
# # Let's Begin With DEEP Learning (**ANN**)

# %% [markdown]
# model = seqential()
#
# layer(3,Activation Funtion)
#
# layer(1, Activation Function)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(3,activation='sigmoid',input_dim=11))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 3)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40 (160.00 B)
#  Trainable params: 40 (160.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(x_train,y_train, epochs=10)
# Out:
# Epoch 1/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.3334 - loss: 0.7428
# Epoch 2/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.8050 - loss: 0.5952
# Epoch 3/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7913 - loss: 0.5591
# Epoch 4/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7997 - loss: 0.5323
# Epoch 5/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7908 - loss: 0.5349
# Epoch 6/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7926 - loss: 0.5271
# Epoch 7/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8051 - loss: 0.5065
# Epoch 8/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7956 - loss: 0.5145
# Epoch 9/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7965 - loss: 0.5108
# Epoch 10/10
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7943 - loss: 0.5118

# %%
model.layers[0].get_weights()
# Out:
# [array([[-0.67491305, -0.31830975, -0.64807093],
#         [-0.5082977 , -0.4544104 ,  0.0814492 ],
#         [ 0.56387424,  0.28528515,  0.29759154],
#         [ 0.19187938,  0.26689246,  0.14960033],
#         [-0.19875154, -0.04400832, -0.59438986],
#         [-0.23227754,  0.34238416, -0.38016745],
#         [-0.44291997,  0.07918963,  0.29611084],
#         [-0.18473847, -0.0872132 ,  0.12722951],
#         [ 0.41397077, -0.24178061, -0.39242926],
#         [-0.0685856 ,  0.4164878 , -0.361369  ],
#         [-0.2429258 , -0.34942022, -0.38112497]], dtype=float32),
#  array([-1.9223023e-02,  7.5278022e-06, -1.4136189e-05], dtype=float32)]

# %%
model.layers[1].get_weights()
# Out:
# [array([[ 0.24216363],
#         [-0.13753547],
#         [-0.46701306]], dtype=float32),
#  array([-0.82205987], dtype=float32)]

# %%
model.predict(x_test_scaled)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# array([[0.25052693],
#        [0.24443254],
#        [0.24363145],
#        ...,
#        [0.28590554],
#        [0.28640613],
#        [0.28118926]], dtype=float32)

# %%
y_log = model.predict(x_test_scaled)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_pred = np.where(y_log>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7975

# %% [markdown]
# # Question
#
# 3 hidden layer
#
# 1st hidden layer 4 neuron
#
# 3st hidden layer 4 neuron
#
# 2nd hidden layer 2 neuron (relu)
#
# output (2)

# %%
model = Sequential()

model.add(Dense(4,activation='relu',input_dim=11))
model.add(Dense(2,activation='softmax'))
model.add(Dense(4,activation='relu'))
model.add(Dense(2,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_10 (Dense)                │ (None, 4)              │            48 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 2)              │            10 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 4)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 2)              │            10 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 80 (320.00 B)
#  Trainable params: 80 (320.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import Adam

# %%
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',  # matches softmax + integer labels
    metrics=['accuracy']
)

# %%
history= model.fit(x_train_scaled,y_train,batch_size=50,epochs=50,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8029 - loss: 0.5373 - val_accuracy: 0.7969 - val_loss: 0.5046
# Epoch 2/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7938 - loss: 0.5060 - val_accuracy: 0.7969 - val_loss: 0.4871
# Epoch 3/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7868 - loss: 0.4985 - val_accuracy: 0.7969 - val_loss: 0.4704
# Epoch 4/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8029 - loss: 0.4582 - val_accuracy: 0.7969 - val_loss: 0.4569
# Epoch 5/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7972 - loss: 0.4580 - val_accuracy: 0.7969 - val_loss: 0.4462
# Epoch 6/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7915 - loss: 0.4517 - val_accuracy: 0.7969 - val_loss: 0.4395
# Epoch 7/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7941 - loss: 0.4429 - val_accuracy: 0.7969 - val_loss: 0.4345
# Epoch 8/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7925 - loss: 0.4300 - val_accuracy: 0.7969 - val_loss: 0.4310
# Epoch 9/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7996 - loss: 0.4172 - val_accuracy: 0.7969 - val_loss: 0.4262
# Epoch 10/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7941 - loss: 0.4246 - val_accuracy: 0.7969 - val_loss: 0.4207
# Epoch 11/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8050 - loss: 0.4063 - val_accuracy: 0.8194 - val_loss: 0.4145
# Epoch 12/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8148 - loss: 0.4095 - val_accuracy: 0.8206 - val_loss: 0.4101
# Epoch 13/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8262 - loss: 0.4053 - val_accuracy: 0.8188 - val_loss: 0.4058
# Epoch 14/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8386 - loss: 0.3836 - val_accuracy: 0.8231 - val_loss: 0.4017
# Epoch 15/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8405 - loss: 0.3920 - val_accuracy: 0.8269 - val_loss: 0.3979
# Epoch 16/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8419 - loss: 0.3856 - val_accuracy: 0.8306 - val_loss: 0.3937
# Epoch 17/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8449 - loss: 0.3789 - val_accuracy: 0.8344 - val_loss: 0.3901
# Epoch 18/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8501 - loss: 0.3706 - val_accuracy: 0.8369 - val_loss: 0.3866
# Epoch 19/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8525 - loss: 0.3737 - val_accuracy: 0.8406 - val_loss: 0.3840
# Epoch 20/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8543 - loss: 0.3642 - val_accuracy: 0.8388 - val_loss: 0.3816
# Epoch 21/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8532 - loss: 0.3709 - val_accuracy: 0.8406 - val_loss: 0.3798
# Epoch 22/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8503 - loss: 0.3674 - val_accuracy: 0.8400 - val_loss: 0.3782
# Epoch 23/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8538 - loss: 0.3651 - val_accuracy: 0.8419 - val_loss: 0.3769
# Epoch 24/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8569 - loss: 0.3636 - val_accuracy: 0.8406 - val_loss: 0.3753
# Epoch 25/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8607 - loss: 0.3542 - val_accuracy: 0.8469 - val_loss: 0.3739
# Epoch 26/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8492 - loss: 0.3652 - val_accuracy: 0.8456 - val_loss: 0.3731
# Epoch 27/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8542 - loss: 0.3610 - val_accuracy: 0.8456 - val_loss: 0.3718
# Epoch 28/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8567 - loss: 0.3602 - val_accuracy: 0.8444 - val_loss: 0.3706
# Epoch 29/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8568 - loss: 0.3615 - val_accuracy: 0.8500 - val_loss: 0.3698
# Epoch 30/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8653 - loss: 0.3448 - val_accuracy: 0.8494 - val_loss: 0.3690
# Epoch 31/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8515 - loss: 0.3660 - val_accuracy: 0.8481 - val_loss: 0.3679
# Epoch 32/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8560 - loss: 0.3527 - val_accuracy: 0.8487 - val_loss: 0.3670
# Epoch 33/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8569 - loss: 0.3554 - val_accuracy: 0.8469 - val_loss: 0.3671
# Epoch 34/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8553 - loss: 0.3524 - val_accuracy: 0.8519 - val_loss: 0.3661
# Epoch 35/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8545 - loss: 0.3631 - val_accuracy: 0.8481 - val_loss: 0.3653
# Epoch 36/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8628 - loss: 0.3458 - val_accuracy: 0.8550 - val_loss: 0.3643
# Epoch 37/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8566 - loss: 0.3525 - val_accuracy: 0.8556 - val_loss: 0.3642
# Epoch 38/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8638 - loss: 0.3396 - val_accuracy: 0.8531 - val_loss: 0.3642
# Epoch 39/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8606 - loss: 0.3510 - val_accuracy: 0.8550 - val_loss: 0.3633
# Epoch 40/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8602 - loss: 0.3436 - val_accuracy: 0.8550 - val_loss: 0.3629
# Epoch 41/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8670 - loss: 0.3424 - val_accuracy: 0.8544 - val_loss: 0.3628
# Epoch 42/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8579 - loss: 0.3439 - val_accuracy: 0.8537 - val_loss: 0.3623
# Epoch 43/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8616 - loss: 0.3553 - val_accuracy: 0.8575 - val_loss: 0.3619
# Epoch 44/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8534 - loss: 0.3573 - val_accuracy: 0.8562 - val_loss: 0.3621
# Epoch 45/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8560 - loss: 0.3499 - val_accuracy: 0.8562 - val_loss: 0.3618
# Epoch 46/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8579 - loss: 0.3534 - val_accuracy: 0.8581 - val_loss: 0.3616
# Epoch 47/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8585 - loss: 0.3447 - val_accuracy: 0.8575 - val_loss: 0.3612
# Epoch 48/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8648 - loss: 0.3451 - val_accuracy: 0.8544 - val_loss: 0.3612
# Epoch 49/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8659 - loss: 0.3423 - val_accuracy: 0.8569 - val_loss: 0.3605
# Epoch 50/50
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8672 - loss: 0.3412 - val_accuracy: 0.8594 - val_loss: 0.3604

# %% [markdown]
# Need to fix issues

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
history.history
# Out:
# {'accuracy': [0.7957812547683716,
#   0.7957812547683716,
#   0.7957812547683716,
#   0.7957812547683716,
#   0.7957812547683716,
#   0.7957812547683716,
#   0.7957812547683716,
#   0.7957812547683716,
#   0.7957812547683716,
#   0.7987499833106995,
#   0.8123437762260437,
#   0.8215625286102295,
#   0.8265625238418579,
#   0.831250011920929,
#   0.8365625143051147,
#   0.8417187333106995,
#   0.8440625071525574,
#   0.8464062213897705,
#   0.8479687571525574,
#   0.8521875143051147,
#   0.8517187237739563,
#   0.8514062762260437,
#   0.8521875143051147,
#   0.8526562452316284,
#   0.85546875,
#   0.8560937643051147,
#   0.8568750023841858,
#   0.8564062714576721,
#   0.8568750023841858,
#   0.8559374809265137,
#   0.8570312261581421,
#   0.8576562404632568,
#   0.8584374785423279,
#   0.8576562404632568,
#   0.8581249713897705,
#   0.8596875071525574,
#   0.8603125214576721,
#   0.8579687476158142,
#   0.859375,
#   0.860156238079071,
#   0.8592187762260437,
#   0.8587499856948853,
#   0.8615624904632568,
#   0.8603125214576721,
#   0.8620312213897705,
#   0.8618749976158142,
#   0.8596875071525574,
#   0.8614062666893005,
#   0.8621875047683716,
#   0.8621875047683716],
#  'loss': [0.5274266600608826,
#   0.4984297454357147,
#   0.48156142234802246,
#   0.4671690762042999,
#   0.4554012417793274,
#   0.4462314546108246,
#   0.4391806721687317,
#   0.4327773153781891,
#   0.4257877469062805,
#   0.4184706509113312,
#   0.41200798749923706,
#   0.40647831559181213,
#   0.40195488929748535,
#   0.3975490927696228,
#   0.3929870128631592,
#   0.38873785734176636,
#   0.38421154022216797,
#   0.38027775287628174,
#   0.3763418197631836,
#   0.37285032868385315,
#   0.3702811002731323,
#   0.36781013011932373,
#   0.36566534638404846,
#   0.3640314042568207,
#   0.3623594045639038,
#   0.3610615134239197,
#   0.3598122000694275,
#   0.3584021031856537,
#   0.357504665851593,
#   0.35658568143844604,
#   0.3553765118122101,
#   0.35470855236053467,
#   0.3533761203289032,
#   0.3528561294078827,
#   0.35179153084754944,
#   0.3513045608997345,
#   0.3507249355316162,
#   0.3497493863105774,
#   0.34924259781837463,
#   0.3485766649246216,
#   0.3483569622039795,
#   0.348112016916275,
#   0.3475821316242218,
#   0.3470640480518341,
#   0.34723663330078125,
#   0.34658515453338623,
#   0.34623032808303833,
#   0.34614506363868713,
#   0.34575366973876953,
#   0.3456084728240967],
#  'val_accuracy': [0.796875,
#   0.796875,
#   0.796875,
#   0.796875,
#   0.796875,
#   0.796875,
#   0.796875,
#   0.796875,
#   0.796875,
#   0.796875,
#   0.8193749785423279,
#   0.8206250071525574,
#   0.8187500238418579,
#   0.8231250047683716,
#   0.8268749713897705,
#   0.8306249976158142,
#   0.8343750238418579,
#   0.8368750214576721,
#   0.840624988079071,
#   0.8387500047683716,
#   0.840624988079071,
#   0.8399999737739563,
#   0.8418750166893005,
#   0.840624988079071,
#   0.846875011920929,
#   0.8456249833106995,
#   0.8456249833106995,
#   0.8443750143051147,
#   0.8500000238418579,
#   0.8493750095367432,
#   0.8481249809265137,
#   0.8487499952316284,
#   0.846875011920929,
#   0.8518750071525574,
#   0.8481249809265137,
#   0.8550000190734863,
#   0.8556249737739563,
#   0.8531249761581421,
#   0.8550000190734863,
#   0.8550000190734863,
#   0.8543750047683716,
#   0.8537499904632568,
#   0.8575000166893005,
#   0.856249988079071,
#   0.856249988079071,
#   0.8581249713897705,
#   0.8575000166893005,
#   0.8543750047683716,
#   0.8568750023841858,
#   0.859375],
#  'val_loss': [0.5046272873878479,
#   0.48710769414901733,
#   0.47043201327323914,
#   0.45688381791114807,
#   0.4462161362171173,
#   0.43947792053222656,
#   0.43448731303215027,
#   0.43096107244491577,
#   0.4261844754219055,
#   0.4207233786582947,
#   0.41449251770973206,
#   0.4101372957229614,
#   0.40583160519599915,
#   0.40171706676483154,
#   0.39791515469551086,
#   0.39369839429855347,
#   0.39008376002311707,
#   0.3865991532802582,
#   0.38403016328811646,
#   0.3815566599369049,
#   0.37978217005729675,
#   0.3782024085521698,
#   0.3768812119960785,
#   0.3752892017364502,
#   0.37390124797821045,
#   0.37310412526130676,
#   0.3717869520187378,
#   0.3706471621990204,
#   0.36978256702423096,
#   0.36897629499435425,
#   0.3679005801677704,
#   0.3670464754104614,
#   0.3671480119228363,
#   0.36605170369148254,
#   0.36527276039123535,
#   0.36427855491638184,
#   0.3641584515571594,
#   0.3642086684703827,
#   0.3633076548576355,
#   0.3628794848918915,
#   0.36280858516693115,
#   0.3623136579990387,
#   0.36194083094596863,
#   0.36211666464805603,
#   0.36181098222732544,
#   0.3615556061267853,
#   0.3611821234226227,
#   0.3612031936645508,
#   0.36045390367507935,
#   0.36040160059928894]}

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %% [markdown]
# # Home Task:
#
# USING heart dataset , apply neural networks,
# with 3 hidden netwroks , 11 neurons, output 2 layers, now find out the test accuracy , train, test and display knowledge graph with 3 major features with 20 rows.
